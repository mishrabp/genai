# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)
# </center>

# %% [markdown]
# ##**Index:**

# %% [markdown]
# 1. Setup
#
# 2. Pre-processing
#
# 3. Extract and Evaluate Output

# %% [markdown]
# <p align="right">
# <img src="data:image/png;base64,..." height="380" width="300"></p>

# %% [markdown]
# ## **1. Setup**

# %% [markdown]
# ###**Steps:**
#
# 1.1 Installation and Import
#
# 1.2 Authentication

# %% [markdown]
# <p align="right">
# <img src="data:image/png;base64,..." height="350" width="300"></p>

# %% [markdown]
# ###**1.1 Installation and import**

# %%
# !pip install -q openai==1.55.3 datasets evaluate rouge_score bert_score
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.9/219.9 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 53.0 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done

# %%
import pandas as pd
from openai import AzureOpenAI
from datasets import load_dataset
from evaluate import load
from tqdm import tqdm
import json

# %% [markdown]
# ###**1.2 Authentication**

# %%
with open('config.json', 'r') as az_creds:
    data = az_creds.read()

# %%
data
# Out:
# '{\n    "AZURE_OPENAI_KEY": "346ebbcb19444213b6f9de2218df6ef8",\n    "AZURE_OPENAI_ENDPOINT": "https://jalajtest.openai.azure.com/",\n    "AZURE_OPENAI_APIVERSION": "2024-02-15-preview",\n    "CHATGPT_MODEL": "MLS"\n}'

# %%
creds = json.loads(data)

# %%
client = AzureOpenAI(
    azure_endpoint=creds["AZURE_OPENAI_ENDPOINT"],
    api_key=creds["AZURE_OPENAI_KEY"],
    api_version=creds["AZURE_OPENAI_APIVERSION"]
)

# %%
deployment_name = creds["CHATGPT_MODEL"]

# %% [markdown]
# ## **2. Pre-processing**

# %% [markdown]
# ###**Steps:**
#
# 2.1 Load Data
#
# 2.2 Verify Data
#
# 2.3 Devise Prompt
#
# 2.4 Create Prompt

# %% [markdown]
# <p align="right">
# <img src="data:image/png;base64,..." height="600" width="320"> </p>

# %% [markdown]
# ###**2.1 Load Data**

# %%
dataset = load_dataset("pgurazada1/dialogsum")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/287 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/29.8k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/24.1k [00:00<?, ?B/s]
# Generating examples split:   0%|          | 0/32 [00:00<?, ? examples/s]
# Generating gold_examples split:   0%|          | 0/32 [00:00<?, ? examples/s]

# %%
dialogue_summary_examples_df = dataset['examples'].to_pandas()
dialogue_summary_gold_examples_df = dataset['gold_examples'].to_pandas()

# %%
examples_df = dialogue_summary_examples_df.sample(4)

# %%
examples_df
# Out:
#                                              dialogue  \
# 29  #Person1#: Are you free on the thirteenth in t...
# 9   #Person1#: Hello. May I help you?\n#Person2#: ...
# 20  #Person1#: Good afternoon. I am Mr. Brown, the...
# 0   #Person1#: Have you gone to school today?\n#Pe...
#
#                                               summary
# 29  #Person1# and #Person2# are arranging for thei...
# 9   #Person2# checks the arrival of #Person2#'s co...
# 20  It has been the fourth time for Mr. Brown to t...
# 0   #Person1# couldn't go to school for the illnes...

# %% [markdown]
# ###**2.2 Verify Data**

# %%
for index, row in examples_df.iterrows():
    print('Example Dialogue:')
    print(row[0])
    print('Example Summary:')
    print(row[1])
    break
# Out:
# Example Dialogue:
# #Person1#: Are you free on the thirteenth in the afternoon?
# #Person2#: No I'm afraid not. I'm meeting Ruth then. How about the fourteenth in the morning?
# #Person1#: I'm sorry. I'm attending a meeting at the Hilton then.
# #Person2#: What about the next day?
# #Person1#: No. I'm busy then too. I'm meeting Dorothy Heath at North Bridge Road. Are you free on Thursday afternoon?
# #Person2#: Yes, I think I am. Let's meet for lunch at mouth restaurant.
# #Person1#: Good idea! Is two o'clock okay?
# #Person2#: That's fine. See you there!
# Example Summary:
# #Person1# and #Person2# are arranging for their next meeting. They decide to meet on Thursday afternoon.

# %% [markdown]
# ###**2.3 Devise Prompt**

# %%
system_message = """
Summarize the dialogue mentioned in the user input. Be specific and concise in your summary.
"""

# %%
few_shot_prompt = [{'role':'system', 'content': system_message}]

# %% [markdown]
# ###**2.4 Create Prompt**

# %%
for index, row in examples_df.iterrows():
    user_input_example = row[0]
    assistant_output_example = row[1]

    few_shot_prompt.append(
        {
            'role': 'user',
            'content': user_input_example
        }
    )

    few_shot_prompt.append(
        {
            'role': 'assistant',
            'content': assistant_output_example
        }
    )

# %%
few_shot_prompt
# Out:
# [{'role': 'system',
#   'content': '\nSummarize the dialogue mentioned in the user input. Be specific and concise in your summary.\n'},
#  {'role': 'user',
#   'content': "#Person1#: Are you free on the thirteenth in the afternoon?\n#Person2#: No I'm afraid not. I'm meeting Ruth then. How about the fourteenth in the morning?\n#Person1#: I'm sorry. I'm attending a meeting at the Hilton then.\n#Person2#: What about the next day?\n#Person1#: No. I'm busy then too. I'm meeting Dorothy Heath at North Bridge Road. Are you free on Thursday afternoon?\n#Person2#: Yes, I think I am. Let's meet for lunch at mouth restaurant.\n#Person1#: Good idea! Is two o'clock okay?\n#Person2#: That's fine. See you there!"},
#  {'role': 'assistant',
#   'content': '#Person1# and #Person2# are arranging for their next meeting. They decide to meet on Thursday afternoon.'},
#  {'role': 'user',
#   'content': "#Person1#: Hello. May I help you?\n#Person2#: Hi. Last month, our company, Turner Interiors of Beijing, ordered some documents under our new L / C. What I want to do is check and see if the documents have arrived yet.\n#Person1#: Let me find that on my screen. . . yes, the L / C is right here. I'm sorry ; the documents don't seem to be here yet.\n#Person2#: Oh, dear. When do you think they will arrive?\n#Person1#: It should be around 5 working days, but different cases take different times. Sorry I can't be more precise."},
#  {'role': 'assistant',
#   'content': "#Person2# checks the arrival of #Person2#'s company's documents with #Person1#'s assistance."},
#  {'role': 'user',
#   'content': "#Person1#: Good afternoon. I am Mr. Brown, the Import manager of Atlantic Industries Ltd, Sidney, Australia. This is my card.\n#Person2#: Good afternoon, Mr. Brown. My name is Mrs. Anderson, manager of the sales department.\n#Person1#: Nice to see you, Mrs. Anderson.\n#Person2#: Nice to see you too, Mr. Brown. Won't you sit down?\n#Person1#: Thank you.\n#Person2#: What would you like, tea or coffee?\n#Person1#: I'd prefer coffee if you don't mind.\n#Person2#: Is it your first trip to the Fair, Mr. Brown?\n#Person1#: No, it's the fourth time.\n#Person2#: Good. Is there anything you find changed about the Fair?\n#Person1#: Yes, a great deal. The business scope has been broadened, and there are more visitors than ever before.\n#Person2#: Really, Mr. Brown? Did you find anything interesting?\n#Person1#: Oh, yes. Quite a bit. But we are especially interested in your products.\n#Person2#: We are glad to hear that. What items are you particularly interested in?\n#Person1#: Women's dresses. They are fashionable and suit Australian women well, too. If they are of high quality and the prices are reasonable, we'll purchase large quantities of them. Will you please quote us a price?\n#Person2#: All right."},
#  {'role': 'assistant',
#   'content': "It has been the fourth time for Mr. Brown to the Fair. Mr. Brown finds something changed and he is interested in Mrs. Anderson's products, especially women's dresses. He would like to know the price."},
#  {'role': 'user',
#   'content': "#Person1#: Have you gone to school today?\n#Person2#: I went to school today. Did you go to school?\n#Person1#: I couldn't go to school today, I was sick.\n#Person2#: That's horrible. I'd be happy to give you the assignments from English class.\n#Person1#: Thank you very much, that's kind of you.\n#Person2#: Don't mention it.\n#Person1#: When you miss a day of school, I'll be happy to give you the English assignments.\n#Person2#: That is greatly appreciated and I hope you feel well enough to go to school tomorrow."},
#  {'role': 'assistant',
#   'content': "#Person1# couldn't go to school for the illness. #Person2#'ll give #Person1# the assignments from English classes."}]

# %% [markdown]
# ## **3. Extract and Evaluate Output**

# %% [markdown]
# ###**Steps:**
#
# 3.1 Extract results
#
# 3.2 Evaluate results

# %% [markdown]
# <p align="right">
# <img src="data:image/png;base64,..." height="360" width="300"> </p>

# %% [markdown]
# ###**3.1 Extract results**

# %%
predictions, ground_truths = [], []

# %%
for index, row in tqdm(dialogue_summary_gold_examples_df.iterrows()):
    gold_dialogue = row[0]
    gold_summary = row[1]

    user_input = [{'role':'user', 'content': gold_dialogue}]

    try:
        response = client.chat.completions.create(
            model=deployment_name,
            messages=few_shot_prompt + user_input
        )

        predictions.append(response.choices[0].message.content)
        ground_truths.append(gold_summary)
    except Exception as e:
        print(e) # Log error and continue
        continue
# Out:
# 32it [00:32,  1.01s/it]

# %%
predictions
# Out:
# ['#Person1# suggests making dinner together instead of a frozen pizza. They agree to make the spicy chicken curry. #Person2# shows difficulties with cooking, but #Person1# offers to teach. They start with washing and chopping vegetables, stir-frying them, cutting and stir-frying chicken before cooking rice along with it. #Person2# prefers white rice.',
#  '#Person1# and #Person2# discuss their interest in art and plan to visit the national gallery for a Greek and Roman sculpture exhibition together.',
#  'Tom has written a letter to Sally and John. It was good for Tom to hear about their upcoming visit in January. Tom has invited them for dinner and also shared his phone number.',
#  "#Person1# is telling #Person2# about #Person1#'s New Year's resolution, which is going on a diet without eating junk food. However, at the end #Person1# asked #Person2# if they have any chips left.",
#  '#Person1# has a reservation note and wants to pick up the ticket. #Person2# asks #Person1# to fill out the ticket booking form and confirms the price of the ticket as $800. #Person1# asks if they can pay by card and #Person2# agrees to it.',
#  "#Person1# calls #Person2# to check on the order of computers but it has been delayed for 2 days. #Person2# gives Steve's number to #Person1#.",
#  '#Person1# tells #Person2# that his novel has won the Nobel Prize, which makes #Person2# extremely surprised and proud. #Person1# compliments him that he deserves it and suggests to celebrate.',
#  "#Person2# shares the details about their company's successful fundraiser, a marathon for the American Cancer Society. The marathon raised several thousand dollars through the ten dollar entrance fee and pledges from sponsors per mile. #Person2# also mentioned that it helped promote the company's image in the community.",
#  '#Person1# has helped Mrs. Thomas in cleaning the yard, sweeping the front steps and taking out the garbage. Mrs. Thomas asks #Person1# to take her dog Oscar out for a walk. James is working on the weekends to save up to buy a bike.',
#  "#Person1# apologizes for the mistakes in goods and assures #Person2# that they will take responsibility and exchange the merchandise. They also mention improvements will be made for future deliveries. #Person2# hopes there won't be any future mistakes.",
#  '#Person2# shares a bad dream with #Person1# and mentions the trouble sleeping because of being worried about getting into the University of Michigan. #Person1# also shares the same worry but tries to stay positive.',
#  '#Person1# warns #Person2# not to touch the wet paint. Then they discuss how careless John Sampson was for walking on the wet cement. Finally, they see the workmen putting up a notice on the wet cement, but they carelessly walk on it themselves.',
#  "#Person1# and #Person2# discuss about Mike's birthday party and confirm their attendance. #Person2# offers to give a ride to #Person1#.",
#  '#Person1# feels sick and has a headache. #Person2# takes the temperature and finds #Person1# has a small fever. #Person2# suggests #Person1# to ask the parents to call the school office in case there is any urgency due to illness.',
#  "#Person1# invited #Person2# to Ruojia's wedding party, which is happening on the same night she got married. #Person1# recognized from social media and email at first, but #Person2# hadn't seen an email yet. #Person1# brings wineglasses and a card to give to the couple, while #Person2# plans on bringing a tea set.",
#  '#Person2# orders a turkey sandwich and chooses beef with vegetables soup and a Diet Coke as the side dish.',
#  '#Person2# is complaining about the noise made by the baggage elevator and requests to change the room. The hotel staff apologizes and informs her about the unavailability of rooms for that day. However, they assure her that she can change her room from the next day.',
#  '#Person1# asks #Person2# for the direction of the Peking University on the map. #Person2# is not very sure and suggests asking the nearby policeman.',
#  '#Person1# enquires about the flight. #Person2# tells #Person1# that the airport is closed and the passengers will stay in the airport hotel for the night. #Person1# mentions her habit of sleeping with lights on, to which #Person2# responds that another passenger also shares the same habit.',
#  '#Person1# blames #Person2# because they allowed someone unexpected inside their home. However, #Person2# defends themselves by explaining that the visitor showed identification and claimed to be from a utilities company.',
#  '#Person1# made a mid-size vehicle reservation named Jimmy Fox. The car rental office informs that there is no mid-sized car available. #Person1# argues that due to the reservation the car should be reserved. Finally, #Person1# accepts a compact car and buys the insurance. Car rental office apologizes and offers discounts for both the insurance and rent fee.',
#  '#Person1# and #Person2# discuss the start of spring. However, the weather remains cold during the night though the days are warmer. Heating has been off for six days causing issues, but #Person1# plans to get some sun in the apartment just like the cat.',
#  "#Person1# is asking for a recommendation for Chinese wine to try and #Person2# suggests Moutan. It's recommended to have Roast Beijing Duck to go with it, which is said to be the best dish the hotel offers and #Person1# decides to give it a try.",
#  "Susan Miller contacts John asking about the memo regarding office procedures. John doesn't know anything about it and apologizes to Susan.",
#  '#Person2# was born in Chicago, grew up in the suburbs, and then moved to Los Angeles at the age of fourteen. #Person2# graduated from Lincoln High School and then went to Europe where they lived in Munich for almost two years.',
#  '#Person1# and #Person2# are going to work and planning to meet later. #Person1# wants to catch a ride with #Person2#. They decide to meet at five.',
#  'Francis and Monica discussed their availability for working together on a financial report. Francis is busy all day long today, and Friday morning is not a good time for him. However, Francis suggested meeting for the report on Friday afternoon from 1-4 PM, and Monica agreed to meet then.',
#  "#Person1# inquires about #Person2#'s proficiency in English and where he learned to speak it. #Person2# mentions that he learned it in college and has been in the U.S. for three weeks. They also discuss #Person2#'s experience in California and Las Vegas.",
#  '#Person1# forgives #Person2# for his absence but is happy to share that she thinks she is pregnant. They go to the doctor and confirm the due date to be October 27th, 2009. However, #Person2# is shocked to learn that he was away during the specific timeframe in February when the baby was conceived. #Person1# is upset and in disbelief.',
#  '#Person1# feels thirsty, and #Person2# suggests getting a drink.  #Person1# mentions wanting to get a soda, but #Person2# explains that water is the best option to quench thirst and suggests getting water instead. #Person1# ends up choosing water instead of soda.',
#  '#Person1# receives an anonymous call from #Person2#. #Person2# does not respond and #Person1# warns them that they will call the police if they call again.',
#  "#Person1# invites #Person2# to go to London with him/her. They discuss on how to get there and #Person2# suggests going by car. #Person1# prefers going by train, which is expensive but quicker. Finally, #Person2# suggests taking an express bus, which isn't discussed further."]

# %% [markdown]
# ###**3.2 Evaluate results**

# %%
rouge_scorer = load("rouge")
bertscore = load("bertscore")
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/7.95k [00:00<?, ?B/s]

# %%
rouge_scorer.compute(
            predictions=predictions,
            references=ground_truths,
        )
# Out:
# {'rouge1': 0.32320128991068914,
#  'rouge2': 0.09956898499591577,
#  'rougeL': 0.24663161906585995,
#  'rougeLsum': 0.2468748685265108}

# %%
results = bertscore.compute(
    predictions=predictions,
    references=ground_truths,
    lang="en"
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
sum(results['f1'])/len(results['f1'])
# Out:
# 0.8971373289823532
